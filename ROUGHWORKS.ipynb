# %%
import pandas as pd

# %%
a = [1,32,3,4]

# %%
df = pd.DataFrame(a)

# %%
df
# Out:
#     0
# 0   1
# 1  32
# 2   3
# 3   4

# %%
df = pd.DataFrame({'date': ['2021-01-13', '2022-10-22']})
df['date'] = pd.to_datetime(df['date'])

# %%
df['date'].value_counts()
# Out:
# date
# 2021-01-13    1
# 2022-10-22    1
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
df_raw = pd.read_csv(r'C:\Users\23180\OneDrive\Desktop\PYTHON PROJECT\CONTENT MONETIZATION\DATASET\RAW\youtube_ad_revenue_dataset.csv')

# %%
df_raw.groupby('category')['ad_revenue_usd'].sum()
# Out:
# category
# Education        5.179408e+06
# Entertainment    5.152672e+06
# Gaming           5.161162e+06
# Lifestyle        5.086830e+06
# Music            5.171730e+06
# Tech             5.182009e+06
# Name: ad_revenue_usd, dtype: float64

# %%
df_raw.groupby('device')['ad_revenue_usd'].sum()
# Out:
# device
# Desktop    7.715838e+06
# Mobile     7.749724e+06
# TV         7.731593e+06
# Tablet     7.736655e+06
# Name: ad_revenue_usd, dtype: float64

# %%
df_raw.isna().sum()
# Out:
# video_id                   0
# date                       0
# views                      0
# likes                   6117
# comments                6112
# watch_time_minutes      6105
# video_length_minutes       0
# subscribers                0
# category                   0
# device                     0
# country                    0
# ad_revenue_usd             0
# dtype: int64

# %%
df_raw.duplicated().sum()
# Out:
# 2400
